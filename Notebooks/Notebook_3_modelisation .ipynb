# %% [markdown]
# # Modélisation
# ### Préparation des features pour la modélisation
# #### A réaliser :
# * Si ce n'est pas déjà fait, supprimer toutes les colonnes peu pertinentes pour la modélisation. OK fait
# * Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer. OK fait
# * Débarrassez-vous des features redondantes en utilisant une matrice de corrélation de Pearson. Pour cela, utiisez la méthode corr() de Pandas, couplé d'un graphique Heatmap de la librairie Seaborn. Ok fait
# * Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé). Ok fait
# * Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).
# * Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne. Les deux méthodes d'encodage à connaitre sont le OneHotEncoder et le LabelEncoder

# %% [markdown]
# ### Débarrassez-vous des features redondantes en utilisant une matrice de corrélation de Pearson. Pour cela, utiisez la méthode corr() de Pandas, couplé d'un graphique Heatmap de la librairie Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 

#Preprocess
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %%
data_etape_2_clean = pd.read_csv(r"..\Fichiers\data_etape_2_clean.csv", keep_default_na=False)

# %% [markdown]
# #### Préparation à une matrice de corrélation

# %%
s = data_etape_2_clean["NumberofBuildings"]
print("dtype:", s.dtype)
print("nunique:", s.nunique(dropna=True))
print("std:", s.std())
print("% NaN:", s.isna().mean())
print(s.value_counts(dropna=False).head())
# Out:
# dtype: float64
# nunique: 9
# std: 0.7806070740941623
# % NaN: 0.0
# NumberofBuildings
# 1.0    1323
# 0.0      42
# 2.0      13
# 3.0      10
# 5.0       7
# Name: count, dtype: int64

# %%
s = data_etape_2_clean["NumberofBuildings"].dropna()

plt.figure()
sns.boxplot(y=s)
plt.xlabel("NumberofBuildings")
plt.title("Boxplot - NumberofBuildings")
plt.show()

data_etape_2_clean.loc[data_etape_2_clean["NumberofBuildings"] == 0, "NumberofBuildings"] = 1

# %%
display(data_etape_2_clean.columns)

colonnes_autorisees = [
    "Latitude",
    "Longitude",
    "YearBuilt",
    "SiteEnergyUse(kBtu)",
    "NumberofFloors",
    "PropertyGFABuilding(s)",
    "LargestPropertyUseTypeGFA",
    "SecondLargestPropertyUseTypeGFA",
    "has_second_use",
    "has_third_use",
    "n_declared_uses",
    "share_primary_gfa",
    "share_second_gfa",
    "parking_share",
    "is_multi_building",
    "has_electricity",
    "has_gas",
    "has_steam",
    "n_energy_sources",
]
cols = [c for c in colonnes_autorisees if c in data_etape_2_clean.columns]
cols = [c for c in cols if data_etape_2_clean[c].dtype.kind in "if"]
corr = data_etape_2_clean[cols].corr(method="pearson").round(2)
print("Colonnes utilisées pour la corrélation :", cols)
display(corr)
display(data_etape_2_clean["NumberofBuildings"])
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'CouncilDistrictCode',
#        'Neighborhood', 'Latitude', 'Longitude', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'SiteEnergyUse(kBtu)', 'has_second_use', 'share_primary_gfa',
#        'share_second_gfa', 'parking_share', 'is_multi_building',
#        'has_electricity', 'has_gas', 'has_steam', 'has_third_use',
#        'n_declared_uses', 'building_age_class', 'n_energy_sources',
#        'zip_group_3'],
#       dtype='object')
# Colonnes utilisées pour la corrélation : ['Latitude', 'Longitude', 'SiteEnergyUse(kBtu)', 'NumberofFloors', 'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA', 'has_second_use', 'has_third_use', 'n_declared_uses', 'share_primary_gfa', 'share_second_gfa', 'parking_share', 'is_multi_building', 'has_electricity', 'has_gas', 'has_steam', 'n_energy_sources']
#                                  Latitude  Longitude  SiteEnergyUse(kBtu)  \
# Latitude                             1.00      -0.11                 0.04
# Longitude                           -0.11       1.00                -0.04
# SiteEnergyUse(kBtu)                  0.04      -0.04                 1.00
# NumberofFloors                       0.08      -0.08                 0.38
# PropertyGFABuilding(s)              -0.02      -0.01                 0.67
# LargestPropertyUseTypeGFA           -0.01      -0.01                 0.64
# SecondLargestPropertyUseTypeGFA      0.02      -0.05                 0.38
# has_second_use                      -0.04      -0.06                 0.10
# has_third_use                        0.00      -0.03                 0.10
# n_declared_uses                      0.01      -0.05                 0.17
# share_primary_gfa                    0.04       0.02                 0.03
# share_second_gfa                     0.02      -0.05                 0.09
# parking_share                        0.11      -0.05                 0.23
# is_multi_building                    0.02       0.06                 0.11
# has_electricity                     -0.08       0.04                 0.05
# has_gas                              0.00       0.06                 0.08
# has_steam                           -0.03      -0.00                 0.17
# n_energy_sources                    -0.03       0.06                 0.15
#
#                                  NumberofFloors  PropertyGFABuilding(s)  \
# Latitude                                   0.08                   -0.02
# Longitude                                 -0.08                   -0.01
# SiteEnergyUse(kBtu)                        0.38                    0.67
# NumberofFloors                             1.00                    0.44
# PropertyGFABuilding(s)                     0.44                    1.00
# LargestPropertyUseTypeGFA                  0.40                    0.92
# SecondLargestPropertyUseTypeGFA            0.33                    0.44
# has_second_use                             0.21                    0.07
# has_third_use                              0.16                    0.09
# n_declared_uses                            0.17                    0.10
# share_primary_gfa                         -0.02                   -0.05
# share_second_gfa                           0.15                    0.03
# parking_share                              0.29                    0.14
# is_multi_building                         -0.06                    0.08
# has_electricity                            0.04                   -0.03
# has_gas                                   -0.15                    0.01
# has_steam                                  0.31                    0.15
# n_energy_sources                           0.00                    0.07
#
#                                  LargestPropertyUseTypeGFA  \
# Latitude                                             -0.01
# Longitude                                            -0.01
# SiteEnergyUse(kBtu)                                   0.64
# NumberofFloors                                        0.40
# PropertyGFABuilding(s)                                0.92
# LargestPropertyUseTypeGFA                             1.00
# SecondLargestPropertyUseTypeGFA                       0.31
# has_second_use                                       -0.07
# has_third_use                                        -0.06
# n_declared_uses                                      -0.07
# share_primary_gfa                                     0.26
# share_second_gfa                                     -0.02
# parking_share                                         0.24
# is_multi_building                                     0.10
# has_electricity                                      -0.03
# has_gas                                              -0.00
# has_steam                                             0.11
# n_energy_sources                                      0.04
#
#                                  SecondLargestPropertyUseTypeGFA  \
# Latitude                                                    0.02
# Longitude                                                  -0.05
# SiteEnergyUse(kBtu)                                         0.38
# NumberofFloors                                              0.33
# PropertyGFABuilding(s)                                      0.44
# LargestPropertyUseTypeGFA                                   0.31
# SecondLargestPropertyUseTypeGFA                             1.00
# has_second_use                                              0.56
# has_third_use                                               0.35
# n_declared_uses                                             0.45
# share_primary_gfa                                          -0.10
# share_second_gfa                                            0.71
# parking_share                                               0.47
# is_multi_building                                          -0.03
# has_electricity                                             0.03
# has_gas                                                    -0.04
# has_steam                                                   0.05
# n_energy_sources                                           -0.01
#
#                                  has_second_use  has_third_use  \
# Latitude                                  -0.04           0.00
# Longitude                                 -0.06          -0.03
# SiteEnergyUse(kBtu)                        0.10           0.10
# NumberofFloors                             0.21           0.16
# PropertyGFABuilding(s)                     0.07           0.09
# LargestPropertyUseTypeGFA                 -0.07          -0.06
# SecondLargestPropertyUseTypeGFA            0.56           0.35
# has_second_use                             1.00           0.52
# has_third_use                              0.52           1.00
# n_declared_uses                            0.72           0.79
# share_primary_gfa                         -0.36          -0.36
# share_second_gfa                           0.70           0.40
# parking_share                              0.24           0.10
# is_multi_building                         -0.07          -0.01
# has_electricity                            0.05           0.02
# has_gas                                   -0.05          -0.02
# has_steam                                  0.02           0.01
# n_energy_sources                          -0.03          -0.01
#
#                                  n_declared_uses  share_primary_gfa  \
# Latitude                                    0.01               0.04
# Longitude                                  -0.05               0.02
# SiteEnergyUse(kBtu)                         0.17               0.03
# NumberofFloors                              0.17              -0.02
# PropertyGFABuilding(s)                      0.10              -0.05
# LargestPropertyUseTypeGFA                  -0.07               0.26
# SecondLargestPropertyUseTypeGFA             0.45              -0.10
# has_second_use                              0.72              -0.36
# has_third_use                               0.79              -0.36
# n_declared_uses                             1.00              -0.39
# share_primary_gfa                          -0.39               1.00
# share_second_gfa                            0.52              -0.07
# parking_share                               0.15               0.32
# is_multi_building                          -0.01               0.11
# has_electricity                             0.03              -0.00
# has_gas                                    -0.00              -0.02
# has_steam                                   0.03              -0.04
# n_energy_sources                            0.02              -0.04
#
#                                  share_second_gfa  parking_share  \
# Latitude                                     0.02           0.11
# Longitude                                   -0.05          -0.05
# SiteEnergyUse(kBtu)                          0.09           0.23
# NumberofFloors                               0.15           0.29
# PropertyGFABuilding(s)                       0.03           0.14
# LargestPropertyUseTypeGFA                   -0.02           0.24
# SecondLargestPropertyUseTypeGFA              0.71           0.47
# has_second_use                               0.70           0.24
# has_third_use                                0.40           0.10
# n_declared_uses                              0.52           0.15
# share_primary_gfa                           -0.07           0.32
# share_second_gfa                             1.00           0.50
# parking_share                                0.50           1.00
# is_multi_building                           -0.05          -0.01
# has_electricity                              0.03           0.04
# has_gas                                     -0.04          -0.14
# has_steam                                   -0.02          -0.02
# n_energy_sources                            -0.04          -0.13
#
#                                  is_multi_building  has_electricity  has_gas  \
# Latitude                                      0.02            -0.08     0.00
# Longitude                                     0.06             0.04     0.06
# SiteEnergyUse(kBtu)                           0.11             0.05     0.08
# NumberofFloors                               -0.06             0.04    -0.15
# PropertyGFABuilding(s)                        0.08            -0.03     0.01
# LargestPropertyUseTypeGFA                     0.10            -0.03    -0.00
# SecondLargestPropertyUseTypeGFA              -0.03             0.03    -0.04
# has_second_use                               -0.07             0.05    -0.05
# has_third_use                                -0.01             0.02    -0.02
# n_declared_uses                              -0.01             0.03    -0.00
# share_primary_gfa                             0.11            -0.00    -0.02
# share_second_gfa                             -0.05             0.03    -0.04
# parking_share                                -0.01             0.04    -0.14
# is_multi_building                             1.00             0.01     0.04
# has_electricity                               0.01             1.00     0.07
# has_gas                                       0.04             0.07     1.00
# has_steam                                    -0.02             0.02    -0.07
# n_energy_sources                              0.03             0.24     0.89
#
#                                  has_steam  n_energy_sources
# Latitude                             -0.03             -0.03
# Longitude                            -0.00              0.06
# SiteEnergyUse(kBtu)                   0.17              0.15
# NumberofFloors                        0.31              0.00
# PropertyGFABuilding(s)                0.15              0.07
# LargestPropertyUseTypeGFA             0.11              0.04
# SecondLargestPropertyUseTypeGFA       0.05             -0.01
# has_second_use                        0.02             -0.03
# has_third_use                         0.01             -0.01
# n_declared_uses                       0.03              0.02
# share_primary_gfa                    -0.04             -0.04
# share_second_gfa                     -0.02             -0.04
# parking_share                        -0.02             -0.13
# is_multi_building                    -0.02              0.03
# has_electricity                       0.02              0.24
# has_gas                              -0.07              0.89
# has_steam                             1.00              0.36
# n_energy_sources                      0.36              1.00
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 1398    1.0
# 1399    1.0
# 1400    1.0
# 1401    1.0
# 1402    1.0
# Name: NumberofBuildings, Length: 1403, dtype: float64

# %% [markdown]
#  * Débarrassez-vous des features redondantes en utilisant une matrice de corrélation de Pearson. Pour cela, utiisez la méthode corr() de Pandas, couplé d'un graphique Heatmap de la librairie Seaborn

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(12, 10))
sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", square=True, cbar_kws={"shrink": 0.8})
plt.title("Matrice de corrélation")
plt.tight_layout()
plt.show()

# %% [markdown]
# En ficant un seuil à 0.7 et -0.7 Il en reste des corrélés mais ils restent tout de même interessants mais bien que corrélés ils ne renseignent pas sur la même chose

# %% [markdown]
# On continue le nettoyage et description

# %% [markdown]
# ### Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer.

# %%
plt.figure(figsize=(6,5))
sns.boxplot(y=data_etape_2_clean["SiteEnergyUse(kBtu)"], width=0.4, fliersize=4)
plt.xlabel("consommation d’énergie(kBtu")
plt.title("Distribution de la consommation d'énergie avec outliers visibles")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Modélisation

# %% [markdown]
# ### Préparation des features pour la modélisation

# %% [markdown]
# #### A réaliser :
# * Si ce n'est pas déjà fait, supprimer toutes les colonnes peu pertinentes pour la modélisation. OK fait
# * Tracer la distribution de la cible pour vous familiariser avec l'ordre de grandeur. En cas d'outliers, mettez en place une démarche pour les supprimer. OK fait
# * Débarrassez-vous des features redondantes en utilisant une matrice de corrélation de Pearson. Pour cela, utiisez la méthode corr() de Pandas, couplé d'un graphique Heatmap de la librairie Seaborn. Ok fait
# * Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé). Ok fait
# * Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).
# * Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne. Les deux méthodes d'encodage à connaitre sont le OneHotEncoder et le LabelEncoder

# %%
# Suppression des valeurs aberrantes sur  par méthode IQR
q1 = data_etape_2_clean["SiteEnergyUse(kBtu)"].quantile(0.25)
q3 = data_etape_2_clean["SiteEnergyUse(kBtu)"].quantile(0.75)
iqr = q3 - q1
lb = q1 - 1.5 * iqr
ub = q3 + 1.5 * iqr
data_etape_2_clean = data_etape_2_clean[data_etape_2_clean["SiteEnergyUse(kBtu)"].between(lb, ub)]

# Boxplot après nettoyage
plt.figure(figsize=(6,5))
sns.boxplot(y=data_etape_2_clean["SiteEnergyUse(kBtu)"], width=0.4, fliersize=4)
plt.xlabel("consommation d’énergie(kBtu)")
plt.title("Distribution de la consommation d'énergie avec outliers visibles")
plt.tight_layout()
plt.show()

# %% [markdown]
# Réalisez différents graphiques pour comprendre le lien entre vos features et la target (boxplots, scatterplots, pairplot si votre nombre de features numériques n'est pas très élevé).

# %%
# Abscisse fixée
abscisse = "SiteEnergyUse(kBtu)"

# Candidats automatiques en ordonnée, numériques, hors identifiants et abscisse
exclusions = {"OSEBuildingID", "ZipCode", "CouncilDistrictCode", abscisse}
candidats = [
    c for c in data_etape_2_clean.select_dtypes(include="number").columns
    if c not in exclusions and data_etape_2_clean[c].nunique(dropna=True) > 1
]

# Libellés en français
libelles = {
    "PropertyGFATotal": "Surface totale (pieds²)",
    "PropertyGFABuilding(s)": "Surface bâtiments (pieds²)",
    "PropertyGFAParking": "Surface parking (pieds²)",
    "NumberofFloors": "Nombre d’étages",
    "YearBuilt": "Année de construction", 
    "NumberofBuildings" : "Nombre de bâtiments",
    
}

# Tracé, une figure par candidat
assert abscisse in data_etape_2_clean.columns, f"Abscisse absente: {abscisse}"
for y in candidats:
    data_xy = data_etape_2_clean[[abscisse, y]].dropna()
    if data_xy.empty:
        continue
    plt.figure()
    plt.scatter(data_xy[abscisse], data_xy[y], s=10, alpha=0.6)
    plt.xlabel(libelles.get(abscisse, abscisse))
    plt.ylabel(libelles.get(y, y))
    plt.title(f"{libelles.get(y, y)} en fonction de {libelles.get(abscisse, abscisse)}")
    plt.tight_layout()
    if y == "PropertyGFABuilding(s)":
        plt.savefig(
            "C:\\Users\\ethan\\OpenClassroom\\Projet_2\\Projet\\Anticipez_les_besoins_\\Graphs\\scatter_SiteEnergyUse_vs_PropertyGFABuildings.png",
            dpi=300,
            bbox_inches="tight"
        )
    elif y == "has_gas":
        plt.savefig(
            "C:\\Users\\ethan\\OpenClassroom\\Projet_2\\Projet\\Anticipez_les_besoins_\\Graphs\\scatter_SiteEnergyUse_vs_has_gas.png",
            dpi=300,
            bbox_inches="tight"
        )
    plt.show()

# %%
vars_hist = [
    ("SiteEnergyUse(kBtu)", "Consommation d'énergie du site (kBtu)"),  # cible
    ("PropertyGFABuilding(s)", "Surface totale (pieds²)"),
    ("SecondLargestPropertyUseTypeGFA", "Surface du 2ᵉ usage (pieds²)"),
]

for var, label in vars_hist:
    assert var in data_etape_2_clean.columns, f"Variable absente : {var}"

    # Série brute et version positive (pour le log)
    serie = data_etape_2_clean[var].dropna()
    serie_pos = serie[serie > 0]

    # Si aucune donnée exploitable, on passe
    if serie.empty or serie_pos.empty:
        continue

    # Figure avec 2 sous-graphiques : brut vs log10
    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    # Histogramme brut
    axes[0].hist(serie, bins=50)
    axes[0].set_title(f"Histogramme de {label} (brut)")
    axes[0].set_xlabel(label)
    axes[0].set_ylabel("Effectif")

    # Histogramme transformé en log10
    axes[1].hist(np.log10(serie_pos), bins=50)
    axes[1].set_title(f"Histogramme de log10({label})")
    axes[1].set_xlabel(f"log10({label})")
    axes[1].set_ylabel("Effectif")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Création de colonnes interessantes

# %% [markdown]
# ### Séparez votre jeu de données en un Pandas DataFrame X (ensemble de feautures) et Pandas Series y (votre target).

# %%
cible = "SiteEnergyUse(kBtu)"

colonnes_a_exclure = [cible]

X = data_etape_2_clean.drop(columns=[c for c in colonnes_a_exclure])
y = data_etape_2_clean[cible]

display(X.head())
# Out:
#      BuildingType PrimaryPropertyType  CouncilDistrictCode Neighborhood  \
# 0  NonResidential               Hotel                    7     DOWNTOWN
# 1  NonResidential               Hotel                    7     DOWNTOWN
# 2  NonResidential               Hotel                    7     DOWNTOWN
# 4  NonResidential               Hotel                    7     DOWNTOWN
# 5  NonResidential               Other                    7     DOWNTOWN
#
#    Latitude  Longitude  NumberofBuildings  NumberofFloors  PropertyGFAParking  \
# 0  47.61220 -122.33799                1.0              12                   0
# 1  47.61317 -122.33393                1.0              11               15064
# 2  47.61412 -122.33664                1.0              10                   0
# 4  47.61390 -122.33283                1.0              11                   0
# 5  47.61327 -122.33136                1.0               8                   0
#
#    PropertyGFABuilding(s)  ... parking_share  is_multi_building  \
# 0                   88434  ...      0.000000                  0
# 1                   88502  ...      0.145453                  0
# 2                   61320  ...      0.000000                  0
# 4                   83008  ...      0.000000                  0
# 5                  102761  ...      0.000000                  0
#
#   has_electricity  has_gas has_steam  has_third_use  n_declared_uses  \
# 0               1        1         1              0                1
# 1               1        1         0              1                3
# 2               1        1         1              0                1
# 4               1        1         0              0                1
# 5               1        1         1              0                1
#
#    building_age_class  n_energy_sources    zip_group_3
# 0                   0                 3  seattle_other
# 1                   2                 2  seattle_other
# 2                   0                 3  seattle_other
# 4                   0                 2  seattle_other
# 5                   0                 3  seattle_other
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Si vous avez des features catégorielles, il faut les encoder pour que votre modèle fonctionne. Les deux méthodes d'encodage à connaitre sont le OneHotEncoder et le LabelEncoder

# %% [markdown]
# Export de X pour mieux visualiser

# %%
# CSV
X.to_csv("X_export.csv", index=False)
print("Écrit X_export.csv")
# Out:
# Écrit X_export.csv

# %% [markdown]
# Encodage

# %% [markdown]
# OneHotEncoder méthode

# %%
# Colonnes catégorielles explicites
cols_cat = [
    "BuildingType",
    "PrimaryPropertyType",
    "LargestPropertyUseType", 
    "CouncilDistrictCode",
    "SecondLargestPropertyUseType",
    "ThirdLargestPropertyUseType",
    "Neighborhood",
    "zip_group_3",
    
]

# On encode uniquement ces colonnes-là
X_OHE = pd.get_dummies(X, columns=cols_cat, drop_first=False)

print("Forme finale de X_OHE :", X_OHE.shape)
display(X_OHE.head())
# Out:
# Forme finale de X_OHE : (1292, 201)
#    Latitude  Longitude  NumberofBuildings  NumberofFloors  PropertyGFAParking  \
# 0  47.61220 -122.33799                1.0              12                   0
# 1  47.61317 -122.33393                1.0              11               15064
# 2  47.61412 -122.33664                1.0              10                   0
# 4  47.61390 -122.33283                1.0              11                   0
# 5  47.61327 -122.33136                1.0               8                   0
#
#    PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# 0                   88434                    88434.0
# 1                   88502                    83880.0
# 2                   61320                    61320.0
# 4                   83008                    81352.0
# 5                  102761                   102761.0
#
#    SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  \
# 0                              0.0                             0.0
# 1                          15064.0                          4622.0
# 2                              0.0                             0.0
# 4                              0.0                             0.0
# 5                              0.0                             0.0
#
#    has_second_use  ...  Neighborhood_MAGNOLIA / QUEEN ANNE  \
# 0               0  ...                               False
# 1               1  ...                               False
# 2               0  ...                               False
# 4               0  ...                               False
# 5               0  ...                               False
#
#    Neighborhood_NORTH  Neighborhood_NORTHEAST  Neighborhood_NORTHWEST  \
# 0               False                   False                   False
# 1               False                   False                   False
# 2               False                   False                   False
# 4               False                   False                   False
# 5               False                   False                   False
#
#    Neighborhood_North  Neighborhood_Northwest  Neighborhood_SOUTHEAST  \
# 0               False                   False                   False
# 1               False                   False                   False
# 2               False                   False                   False
# 4               False                   False                   False
# 5               False                   False                   False
#
#    Neighborhood_SOUTHWEST  zip_group_3_other_980  zip_group_3_seattle_other
# 0                   False                  False                       True
# 1                   False                  False                       True
# 2                   False                  False                       True
# 4                   False                  False                       True
# 5                   False                  False                       True
#
# [5 rows x 201 columns]

# %% [markdown]
# LabelEncoder

# %%
# Méthode 2, Label Encoding sur toutes les catégorielles
X_LE = X.copy()
for c in cols_cat:
    X_LE[c] = LabelEncoder().fit_transform(X_LE[c].astype(str))

# %%
na = X_OHE.isna().sum().sort_values(ascending=False)
print(na[na>0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Export en csv

# %%
X_OHE.to_csv(r"C:\Users\ethan\OpenClassroom\Projet_2\Projet\Anticipez_les_besoins_\Fichiers\data_etape_3_clean_X.csv", index=False)
y.to_csv(r"C:\Users\ethan\OpenClassroom\Projet_2\Projet\Anticipez_les_besoins_\Fichiers\data_etape_3_clean_y.csv", index= False)
