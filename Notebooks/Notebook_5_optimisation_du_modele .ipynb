# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
#Selection
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV, 
    cross_validate,
)
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_error 
from sklearn.inspection import permutation_importance

#Preprocess
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

#Modèles
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Optimisation et interprétation du modèle

# %% [markdown]
# #### A réaliser :
# * Reprennez le meilleur algorithme que vous avez sécurisé via l'étape précédente, et réalisez une GridSearch de petite taille sur au moins 3 hyperparamètres.
# * Si le meilleur modèle fait partie de la famille des modèles à arbres (RandomForest, GradientBoosting) alors utilisez la fonctionnalité feature importance pour identifier les features les plus impactantes sur la performance du modèle. Sinon, utilisez la méthode Permutation Importance de sklearn.

# %%
X_OHE = pd.read_csv(r"..\Fichiers\data_etape_3_clean_X.csv", keep_default_na=False)
y = pd.read_csv(r"..\Fichiers\data_etape_3_clean_y.csv", keep_default_na=False)

# %%
print(X_OHE.columns.tolist())
# Out:
# ['Latitude', 'Longitude', 'NumberofBuildings', 'NumberofFloors', 'PropertyGFAParking', 'PropertyGFABuilding(s)', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseTypeGFA', 'has_second_use', 'share_primary_gfa', 'share_second_gfa', 'parking_share', 'is_multi_building', 'has_electricity', 'has_gas', 'has_steam', 'has_third_use', 'n_declared_uses', 'building_age_class', 'n_energy_sources', 'BuildingType_Campus', 'BuildingType_Multifamily LR (1-4)', 'BuildingType_Multifamily MR (5-9)', 'BuildingType_NonResidential', 'BuildingType_Nonresidential COS', 'BuildingType_Nonresidential WA', 'BuildingType_SPS-District K-12', 'PrimaryPropertyType_Distribution Center', 'PrimaryPropertyType_Hospital', 'PrimaryPropertyType_Hotel', 'PrimaryPropertyType_K-12 School', 'PrimaryPropertyType_Laboratory', 'PrimaryPropertyType_Large Office', 'PrimaryPropertyType_Medical Office', 'PrimaryPropertyType_Mixed Use Property', 'PrimaryPropertyType_Office', 'PrimaryPropertyTyp
# ...

# %% [markdown]
# ### --- RandomForest ---

# %%
# Copies dédiées
X_rf = X_OHE.copy()
y_rf = y.copy()

# %%
# Split
Xtr, Xte, ytr, yte = train_test_split(X_rf, y_rf, test_size=0.2, random_state=42)

# %%
# Définition du modèle et de la grille
rf_base = RandomForestRegressor(random_state=42, n_jobs=-1, max_samples = 0.7)

param_grid = {
    "n_estimators": [300, 500],
    "max_depth": [12, 16, None],
    "min_samples_leaf": [2, 5, 10],
    "min_samples_split": [2, 10, 20],
    "max_features": ["sqrt", 0.5]
}
gs = GridSearchCV(
    estimator=rf_base,
    param_grid=param_grid,
    scoring="neg_mean_absolute_error",
    cv=3,
    n_jobs=-1
)

gs.fit(Xtr, ytr)
# --- Graphique des résultats de GridSearch ---

# Résultats de la grille sous forme de DataFrame
cv_results = pd.DataFrame(gs.cv_results_)

# On convertit le score (neg_mean_absolute_error) en MAE positive
cv_results["mean_MAE"] = -cv_results["mean_test_score"]
cv_results["std_MAE"] = cv_results["std_test_score"]

# On garde les colonnes utiles
cols = [
    "mean_MAE", "std_MAE", "rank_test_score",
    "param_n_estimators", "param_max_depth",
    "param_min_samples_leaf", "param_min_samples_split",
    "param_max_features"
]
cv_results = cv_results[cols]

# Classement par performance (rank_test_score)
cv_results = cv_results.sort_values("rank_test_score")

# On ne trace que les 15 meilleures combinaisons
top = cv_results.head(15).copy()

# Étiquette lisible pour chaque combinaison d'hyperparamètres
top["label"] = (
    "n=" + top["param_n_estimators"].astype(str)
    + ", depth=" + top["param_max_depth"].astype(str)
    + ", leaf=" + top["param_min_samples_leaf"].astype(str)
)

plt.figure(figsize=(10, 6))

# Barres horizontales : plus la MAE est basse, meilleur est le modèle
plt.barh(range(len(top)), top["mean_MAE"], xerr=top["std_MAE"])
plt.gca().invert_yaxis()  # meilleure combinaison tout en haut

plt.yticks(range(len(top)), top["label"])
plt.xlabel("MAE moyenne (validation croisée)")
plt.title("GridSearch Random Forest – Top 15 combinaisons (MAE CV)")

plt.grid(axis="x", linestyle="--", alpha=0.4)
plt.tight_layout()

plt.savefig(
    r"C:\Users\ethan\OpenClassroom\Projet_2\Projet\Anticipez_les_besoins_\Graphs\rf_gridsearch_top15_mae.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

best_rf = gs.best_estimator_
print("Meilleurs hyperparamètres:", gs.best_params_)
# Out:
# c:\Users\ethan\Anconda4\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Meilleurs hyperparamètres: {'max_depth': 12, 'max_features': 0.5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}

# %%
# Validation croisée du meilleur modèle pour R2, MAE, RMSE
scoring = {"r2": "r2", "mae": "neg_mean_absolute_error", "rmse": "neg_root_mean_squared_error"}
cv_res = cross_validate(best_rf, Xtr, ytr, cv=5, scoring=scoring, return_train_score=False)
cv_r2   = cv_res["test_r2"].mean()
cv_mae  = -cv_res["test_mae"].mean()
cv_rmse = -cv_res["test_rmse"].mean()
zip
# Out:
# c:\Users\ethan\Anconda4\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ethan\Anconda4\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\ethan\Anconda4\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
# Entraînement complet puis métriques cohérentes
best_rf.fit(Xtr, ytr)
yp_tr = best_rf.predict(Xtr)
yp_te = best_rf.predict(Xte)

r2_tr   = r2_score(ytr, yp_tr);  mae_tr  = mean_absolute_error(ytr, yp_tr);  rmse_tr = root_mean_squared_error(ytr, yp_tr)
r2_te   = r2_score(yte, yp_te);  mae_te  = mean_absolute_error(yte, yp_te);  rmse_te = root_mean_squared_error(yte, yp_te)
# Out:
# c:\Users\ethan\Anconda4\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
print(f"RF-GS, CV R2 moyen {cv_r2:.3f}, CV MAE moyen {cv_mae:.2f}, CV RMSE moyen {cv_rmse:.2f}")
print(f"RF-GS, Train  R2 {r2_tr:.3f}, MAE {mae_tr:.2f}, RMSE {rmse_tr:.2f}")
print(f"RF-GS, Test   R2 {r2_te:.3f}, MAE {mae_te:.2f}, RMSE {rmse_te:.2f}")
# Out:
# RF-GS, CV R2 moyen 0.559, CV MAE moyen 1043758.67, CV RMSE moyen 1458965.40
# RF-GS, Train  R2 0.822, MAE 672752.39, RMSE 930002.96
# RF-GS, Test   R2 0.444, MAE 1117476.97, RMSE 1591993.91

# %% [markdown]
# utilisez la fonctionnalité feature importance pour identifier les features les plus impactantes sur la performance du modèle

# %%
# Importances de variables de la Random Forest
importances = best_rf.feature_importances_
feat_names = Xtr.columns
imp = pd.Series(importances, index=feat_names).sort_values(ascending=False)

print("Top 20 des features les plus importantes")
print(imp.head(20).to_string())

# Visualisation élaborée des importances de variables (top 20)

top_n = 20

# Top N features, inversées pour avoir la plus importante en haut
imp_top = imp.head(top_n)[::-1]

values = imp_top.values
vmin, vmax = values.min(), values.max()
norm = (values - vmin) / (vmax - vmin + 1e-12)

# Dégradé de couleurs
colors = plt.cm.viridis(norm)

fig, ax = plt.subplots(figsize=(10, 6))

# Fond transparent
fig.patch.set_alpha(0)
ax.set_facecolor("none")

# Barres horizontales
bars = ax.barh(range(len(imp_top)), values, color=colors)

# Noms des features
ax.set_yticks(range(len(imp_top)))
ax.set_yticklabels(imp_top.index)

# Labels numériques à l’intérieur des barres
ax.bar_label(
    bars,
    fmt="%.3f",
    padding=3,
    fontsize=9
)

# Labels et titre
ax.set_xlabel("Importance de la variable (feature_importances_)")
ax.set_title("Top 20 des variables les plus importantes – Random Forest")

# Grille verticale légère
ax.xaxis.grid(True, linestyle="--", alpha=0.4)
ax.set_axisbelow(True)

fig.tight_layout()

fig.savefig(
    "C:\\Users\\ethan\\OpenClassroom\\Projet_2\\Projet\\Anticipez_les_besoins_\\Graphs\\rf_feature_importances_top20.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True
)

plt.show()
# Out:
# Top 20 des features les plus importantes
# PropertyGFABuilding(s)                               0.308836
# LargestPropertyUseTypeGFA                            0.193396
# SecondLargestPropertyUseTypeGFA                      0.047077
# Latitude                                             0.031644
# NumberofFloors                                       0.029998
# Longitude                                            0.026006
# share_primary_gfa                                    0.025461
# PrimaryPropertyType_Supermarket / Grocery Store      0.022972
# PropertyGFAParking                                   0.018114
# LargestPropertyUseType_Supermarket/Grocery Store     0.015296
# share_second_gfa                                     0.014629
# n_energy_sources                                     0.013578
# n_declared_uses                                      0.013371
# ThirdLargestPropertyUseTypeGFA                       0.012372
# ...
